# %% [markdown]
# # Versuch 2 - Code
#
# 1. Aufgabe - Aufnahme und Analyse eines Grauwertkeiles

# %% [markdown]
# *Belichtungsparameter:*
# Belichtung: -6
# Helligkeit: 150
# Kontrast: 32
# Sättigung: 27
# Schärfe: 119
# Weißabgleich: 7400
# Hintergrund: 1
# Verstärkung: 10
# Leistungsfrequenz: 60 Hz

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

image = cv2.imread("aufgabe1.png") #Bild einlesen 
image = image.astype('float32') #in float umwandeln 

height, width = image.shape[:2]

schwarz = image[0:height, 0:131]
dunkelgrau = image[0:height, 131:270]
mittelgrau = image[0:height, 270:410]
hellgrau = image[0:height, 410:550]
weiß = image[0:height, 550:640]


cv2.imwrite("ergebnis_aufgabe1/black.png", schwarz.astype('uint8'))
cv2.imwrite("ergebnis_aufgabe1/dark1.png", dunkelgrau.astype('uint8'))
cv2.imwrite("ergebnis_aufgabe1/dark2.png", mittelgrau.astype('uint8'))
cv2.imwrite("ergebnis_aufgabe1/dark3.png", hellgrau.astype('uint8'))
cv2.imwrite("ergebnis_aufgabe1/white.png", weiß.astype('uint8'))



# Berechnen von Standardabweichung und Mittelwert für jeden Zuschnitt
results = {
    "schwarz": {"std": np.std(schwarz), "mean": np.mean(schwarz)},
    "dunkelgrau": {"std": np.std(dunkelgrau), "mean": np.mean(dunkelgrau)},
    "mittelgrau": {"std": np.std(mittelgrau), "mean": np.mean(mittelgrau)},
    "hellgrau": {"std": np.std(hellgrau), "mean": np.mean(hellgrau)},
    "weiß": {"std": np.std(weiß), "mean": np.mean(weiß)}
}

# Ausgabe der Ergebnisse
print("Bereich      | Standardabweichung | Mittelwert")
print("----------------------------------------------")
for label, values in results.items():
    print("{:<12} | {} | {}".format(label, round(values["std"], 6), round(values["mean"], 6)))
# Out:
# Bereich      | Standardabweichung | Mittelwert
# ----------------------------------------------
# schwarz      | 2.8370320796966553 | 29.443511962890625
# dunkelgrau   | 4.959405899047852 | 67.36009979248047
# mittelgrau   | 5.281680107116699 | 112.04337310791016
# hellgrau     | 5.793315887451172 | 150.98565673828125
# weiß         | 3.7496418952941895 | 195.5585479736328

# %% [markdown]
# 2. Aufgabe - Aufnahme eines Dunkelbildes

# %%
image = "aufgabe2_"
image2 = "aufgabe1.png"
imagearray = []


def darkmean(path):
    for i in range(10):
        img = cv2.imread(f"{path}{i}.png", cv2.IMREAD_GRAYSCALE)
        if img is not None and img.shape[0] > 0 and img.shape[1] > 0:  # Überprüfung auf gültige Größe
            # Skalierung auf gleiche Größe (z.B. 300x300)
            img = cv2.resize(img, (700, 700))
            imagearray.append(img)

    return np.mean(imagearray, axis=0).astype(np.double) #in double umwandeln 

darkmean = darkmean(image)
cv2.imwrite("ergebnis_aufgabe2/darkmean.png", darkmean.astype('uint8'))

def subdarkmean(img):
    img = cv2.imread(img, cv2.IMREAD_GRAYSCALE) #einlesen
    img_gray_resized = cv2.resize(img, (700, 700)) #
    return img_gray_resized - darkmean

new_img = subdarkmean(image2)
cv2.imwrite("ergebnis_aufgabe2/fixedimage.png", new_img.astype('uint8'))

# Funktion zur Kontrastmaximierung aufrufen und kontrastmaximiertes Bild anzeigen
def display_contrast_maximized_dark_image(dark_image):
    # Anwenden der Histogrammnormalisierung
    normalized_image = cv2.normalize(dark_image, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)
    # Anzeigen des kontrastmaximierten Dunkelbilds
    plt.imshow(normalized_image, cmap='gray')
    plt.title('Contrast Maximized Dark Mean Image')
    plt.axis('off')
    plt.show()

display_contrast_maximized_dark_image(darkmean)

# Laden und Anzeigen des fixedimage-Bildes
fixed_img = cv2.imread("ergebnis_aufgabe2/fixedimage.png", cv2.IMREAD_GRAYSCALE)
plt.imshow(fixed_img, cmap='gray')
plt.title('Fixed Image')
plt.axis('off')  # Deaktivieren der Achsenbeschriftungen
plt.show()

# %% [markdown]
# 3. Aufgabe - Aufnahme eines Weißbildes

# %%
image = "aufgabe3_"
image2 = "aufgabe1.png"
dark_image_path = "ergebnis_aufgabe2/darkmean.png"
white_image_path = "ergebnis_aufgabe3/brightmean.png"
imagearray = []


def brightmean(path):
    for i in range(10):
        img = cv2.imread(f"{path}{i}.png", cv2.IMREAD_GRAYSCALE)
        if img is not None and img.shape[0] > 0 and img.shape[1] > 0:  # Überprüfung auf gültige Größe
            # Skalierung auf gleiche Größe
            img = cv2.resize(img, (700, 700))
            imagearray.append(img)

    return np.mean(imagearray, axis=0).astype(np.double) # Mittelwert über alle weißen Bilder berechnen

cv2.imwrite("ergebnis_aufgabe3/brightmean.png", brightmean(image).astype('uint8'))


def normalize_white_image(white_image):
    # Normiere das Weißbild, so dass der Mittelwert 1 ist
    return white_image / np.mean(white_image)

def subtract_dark_and_divide_by_white(input_image, dark_image, white_image):
    # Dunkelbild einlesen und in double umwandeln
    dark_image_gray = cv2.imread(dark_image, cv2.IMREAD_GRAYSCALE).astype(np.double)

    # Weißbild einlesen und in double umwandeln
    white_image_gray = cv2.imread(white_image, cv2.IMREAD_GRAYSCALE).astype(np.double)

    normalized_white_image = normalize_white_image(white_image_gray)

    # Eingangsbild einlesen und in double umwandeln
    input_image_gray = cv2.imread(input_image, cv2.IMREAD_GRAYSCALE).astype(np.double)
    
    # Skalieren des Dunkelbildes auf die Größe des Eingangsbildes
    dark_image_gray_resized = cv2.resize(dark_image_gray, (input_image_gray.shape[1], input_image_gray.shape[0]))

    # Skalieren des Weißbildes auf die Größe des Eingangsbildes
    normalized_white_image_resized = cv2.resize(normalized_white_image, (input_image_gray.shape[1], input_image_gray.shape[0]))

    # Subtrahiere das Dunkelbild
    corrected_image = input_image_gray - dark_image_gray_resized

    # Dividiere durch das normierte und skalierte Weißbild
    final_image = corrected_image / normalized_white_image_resized

    return final_image



# Funktion zur Kontrastmaximierung aufrufen und kontrastmaximiertes Bild anzeigen
def display_contrast_maximized_bright_image(bright_image):
    # Anwenden der Histogrammnormalisierung
    normalized_bright_image = cv2.normalize(bright_image, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)
    # Anzeigen des kontrastmaximierten Dunkelbilds
    plt.imshow(normalized_bright_image, cmap='gray')
    plt.title('Contrast Maximized Bright Mean Image')
    plt.axis('off')
    plt.show()

display_contrast_maximized_bright_image(brightmean(image))

# Laden und Anzeigen des fixedimage-Bildes
#fixed_img = cv2.imread("ergebnis_aufgabe2/fixedimage.png", cv2.IMREAD_GRAYSCALE)
#plt.imshow(fixed_img, cmap='gray')
#plt.title('Fixed Image')
#plt.axis('off')  # Deaktivieren der Achsenbeschriftungen
#plt.show()


# Subtrahiere das Dunkelbild und dividiere durch das normierte Weißbild
result_image = subtract_dark_and_divide_by_white(image2, dark_image_path, white_image_path)

# Speichere das Ergebnisbild
cv2.imwrite("ergebnis_aufgabe3/final_image.png", result_image.astype(np.uint8))

# Anzeigen des kontrastmaximierten Bilds
plt.imshow(result_image, cmap='gray')
plt.title('Corrected and Normalized Image')
plt.axis('off')
plt.show()

# %% [markdown]
# 4. Aufgabe - Pixelfehler

# %%
dark_image = "ergebnis_aufgabe2/darkmean.png"
bright_image = "ergebnis_aufgabe3/brightmean.png"


def hot_pixel(pixel):
	return np.any(pixel > 0)
def stuck_pixel(pixel):
	return np.all(pixel[0] == pixel[1]) and np.all( pixel[1] == pixel[2])
def dead_pixel(pixel):
    return np.all(pixel == 0)


def mark_pixel(image_path, pixel_condition, mark_color=(0, 255, 0)):
    # Lade das Bild
    image = cv2.imread(image_path)

    # Erstelle eine Kopie des Bilds, um die Markierung vorzunehmen
    marked_image = np.copy(image)

    # Überprüfe die Bedingung für jedes Pixel
    for y in range(image.shape[0]):
        for x in range(image.shape[1]):
            if pixel_condition(image[y, x]):
                # Ändere die Farbe des Pixels, um ihn zu markieren
                marked_image[y, x] = mark_color

    return image

# Markiere die Hotpixels im Dunkelbild
marked_dark_image = mark_pixel(dark_image_path, hot_pixel)

# Markiere die Stuckpixels im Dunkelbild
marked_dark_image = mark_pixel(dark_image_path, stuck_pixel)

# Markiere die Deadpixels im Weißbild
marked_white_image = mark_pixel(white_image_path, dead_pixel)


# Anzeige der markierten Bilder
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(marked_dark_image, cmap='gray')
plt.title('Marked Dark Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(marked_white_image, cmap='gray')
plt.title('Marked White Image')
plt.axis('off')

plt.show()

# %% [markdown]
# - Korrektur des Grauwertkeils wurde schon in Aufgabe 3 erledigt (s. Aufgabe 3)

# %%
image = cv2.imread("ergebnis_aufgabe3/fixedimage.png") #korrigierte Grauwertkeil Bild aus Aufgabe 3 einlesen 
image = image.astype('float32') #in float umwandeln 

height, width = image.shape[:2]

schwarz = image[0:height, 0:131]
dunkelgrau = image[0:height, 131:270]
mittelgrau = image[0:height, 270:410]
hellgrau = image[0:height, 410:550]
weiß = image[0:height, 550:640]


cv2.imwrite("ergebnis_aufgabe4/black.png", schwarz.astype('uint8'))
cv2.imwrite("ergebnis_aufgabe4/dark1.png", dunkelgrau.astype('uint8'))
cv2.imwrite("ergebnis_aufgabe4/dark2.png", mittelgrau.astype('uint8'))
cv2.imwrite("ergebnis_aufgabe4/dark3.png", hellgrau.astype('uint8'))
cv2.imwrite("ergebnis_aufgabe4/white.png", weiß.astype('uint8'))



# Berechnen von Standardabweichung und Mittelwert für jeden Zuschnitt
results = {
    "schwarz": {"std": np.std(schwarz), "mean": np.mean(schwarz)},
    "dunkelgrau": {"std": np.std(dunkelgrau), "mean": np.mean(dunkelgrau)},
    "mittelgrau": {"std": np.std(mittelgrau), "mean": np.mean(mittelgrau)},
    "hellgrau": {"std": np.std(hellgrau), "mean": np.mean(hellgrau)},
    "weiß": {"std": np.std(weiß), "mean": np.mean(weiß)}
}

# Ausgabe der Ergebnisse
print("Bereich      | Standardabweichung | Mittelwert")
print("----------------------------------------------")
for label, values in results.items():
    print("{:<12} | {} | {}".format(label, round(values["std"], 6), round(values["mean"], 6)))
# Out:
# Bereich      | Standardabweichung | Mittelwert
# ----------------------------------------------
# schwarz      | 3.6862480640411377 | 79.28699493408203
# dunkelgrau   | 10.550827980041504 | 108.85982513427734
# mittelgrau   | 17.153438568115234 | 147.783935546875
# hellgrau     | 19.1226749420166 | 186.98484802246094
# weiß         | 22.837966918945312 | 220.16661071777344

# %% [markdown]
# *Vergleich zwischen Orginal- und korrigiertem Bild:*
# - die Standardabweichung und der Mittelwert für jeden Bereich im korrigierten Bild ist allgemein höher sind als im Originalbild
# 	dh. die Pixelwerte im korrigierten Bild variieren stärker und sind weniger homogen(=Gleichmäßigkeit) als im Originalbild
